# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('WellsFargoAppStoreReviews.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                 date  \
# 0           0  2024-03-31 22:22:08
# 1           1  2020-01-18 21:09:17
# 2           2  2022-11-10 01:42:47
# 3           3  2023-06-26 20:48:48
# 4           4  2019-09-17 20:18:53
#
#                                    developerResponse  \
# 0  {'id': 42992501, 'body': "We're sorry to hear ...
# 1                                                NaN
# 2  {'id': 33113457, 'body': "We're sorry to hear ...
# 3  {'id': 37367852, 'body': "We're sorry to hear ...
# 4                                                NaN
#
#                                               review  rating  isEdited  \
# 0  Things like ‘report your card lost or stolen’ ...       5     False
# 1  The Wells Fargo app is a very good one - you c...       5     False
# 2  I’ve been a customer for several years now and...       3     False
# 3  Wells Fargo has been banking services to consu...       5     False
# ...

# %%
df['cleaned_review'] = df['review'].str.lower().str.replace('[^\w\s]', '', regex=True)
df.head()
# Out:
#    Unnamed: 0                 date  \
# 0           0  2024-03-31 22:22:08
# 1           1  2020-01-18 21:09:17
# 2           2  2022-11-10 01:42:47
# 3           3  2023-06-26 20:48:48
# 4           4  2019-09-17 20:18:53
#
#                                    developerResponse  \
# 0  {'id': 42992501, 'body': "We're sorry to hear ...
# 1                                                NaN
# 2  {'id': 33113457, 'body': "We're sorry to hear ...
# 3  {'id': 37367852, 'body': "We're sorry to hear ...
# 4                                                NaN
#
#                                               review  rating  isEdited  \
# 0  Things like ‘report your card lost or stolen’ ...       5     False
# 1  The Wells Fargo app is a very good one - you c...       5     False
# 2  I’ve been a customer for several years now and...       3     False
# 3  Wells Fargo has been banking services to consu...       5     False
# ...

# %%
keywords = ['feature', 'function', 'add', 'want', 'wish', 'need']
df_filtered = df[df['cleaned_review'].str.contains('|'.join(keywords))]

# %%
df_filtered.shape[0]
# Out:
# 1427

# %%
df.shape[0]
# Out:
# 2980

# %%
df_filtered.to_csv('Wellspart3.csv')

# %%
df_new = df_filtered

# %%
df_new['waste-column'] = ''
# Out:
# C:\Users\charis\AppData\Local\Temp\ipykernel_13240\2601902377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['waste-column'] = ''

# %%
df_new.head(2)
# Out:
#    Unnamed: 0                 date  \
# 1           1  2020-01-18 21:09:17
# 2           2  2022-11-10 01:42:47
#
#                                    developerResponse  \
# 1                                                NaN
# 2  {'id': 33113457, 'body': "We're sorry to hear ...
#
#                                               review  rating  isEdited  \
# 1  The Wells Fargo app is a very good one - you c...       5     False
# 2  I’ve been a customer for several years now and...       3     False
#
#        userName                                        title  \
# 1  whitewolf361                  Very Nice App, Minor Quirks
# 2          2a2o  Overall meh, still lacking useful features.
#
#                                       cleaned_review waste-column
# 1  the wells fargo app is a very good one  you ca...
# 2  ive been a customer for several years now and ...

# %%
for index, row in df.iterrows():
    df.at[index, 'new_column'] = f"Value_{index+1}"

# %%
df.to_csv('your_file.csv', index=False)

# %%
df.head(4)
# Out:
#    Unnamed: 0                 date  \
# 0           0  2024-03-31 22:22:08
# 1           1  2020-01-18 21:09:17
# 2           2  2022-11-10 01:42:47
# 3           3  2023-06-26 20:48:48
#
#                                    developerResponse  \
# 0  {'id': 42992501, 'body': "We're sorry to hear ...
# 1                                                NaN
# 2  {'id': 33113457, 'body': "We're sorry to hear ...
# 3  {'id': 37367852, 'body': "We're sorry to hear ...
#
#                                               review  rating  isEdited  \
# 0  Things like ‘report your card lost or stolen’ ...       5     False
# 1  The Wells Fargo app is a very good one - you c...       5     False
# 2  I’ve been a customer for several years now and...       3     False
# 3  Wells Fargo has been banking services to consu...       5     False
#
#         userName                                        title  \
# 0   AceOfBaseLoL                Has options that are unusable
# ...
